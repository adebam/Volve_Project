# %% [markdown]
# In this workflow, I am going to Plot and clean the exported dfs from part 1

# %%
#basics
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("src")   # VERY IMPORTANT

# %%
# load the data
df_1 = pd.read_csv('processed_inputs/df1.csv',index_col='DATEPRD', parse_dates=True)
df_2 = pd.read_csv('processed_inputs/df2.csv',index_col='DATEPRD', parse_dates=True)
df_3 = pd.read_csv('processed_inputs/df3.csv',index_col='DATEPRD', parse_dates=True)
df_4 = pd.read_csv('processed_inputs/df4.csv',index_col='DATEPRD', parse_dates=True)
df_5 = pd.read_csv('processed_inputs/df5.csv',index_col='DATEPRD', parse_dates=True)
df_6 = pd.read_csv('processed_inputs/df6.csv',index_col='DATEPRD', parse_dates=True)
df_7 = pd.read_csv('processed_inputs/df7.csv',index_col='DATEPRD', parse_dates=True)

# %%
#explicitly sets the time frequency of  DatetimeIndex to "Daily" (D).
df_1.asfreq('D')
df_2.asfreq('D')
df_3.asfreq('D')
df_4.asfreq('D')
df_5.asfreq('D')
df_6.asfreq('D')
df_7.asfreq('D')
# Out:
#             WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# DATEPRD
# 2007-09-01  NO 15/9-F-5 AH                5769           15/9-F-5
# 2007-09-02  NO 15/9-F-5 AH                5769           15/9-F-5
# 2007-09-03  NO 15/9-F-5 AH                5769           15/9-F-5
# 2007-09-04  NO 15/9-F-5 AH                5769           15/9-F-5
# 2007-09-05  NO 15/9-F-5 AH                5769           15/9-F-5
# ...                    ...                 ...                ...
# 2016-09-14  NO 15/9-F-5 AH                5769           15/9-F-5
# 2016-09-15  NO 15/9-F-5 AH                5769           15/9-F-5
# 2016-09-16  NO 15/9-F-5 AH                5769           15/9-F-5
# 2016-09-17  NO 15/9-F-5 AH                5769           15/9-F-5
# 2016-09-18  NO 15/9-F-5 AH                5769           15/9-F-5
#
#             NPD_FIELD_CODE NPD_FIELD_NAME  NPD_FACILITY_CODE  \
# DATEPRD
# 2007-09-01         3420717          VOLVE             369304
# ...

# %%
from basic_helper_functions import plot_clean_plot
from basic_helper_functions import delete_nans_and_zeros

# %% [markdown]
# # DF1

# %%
plot_clean_plot(df_1)
# Out:
# how many nans before cleaning
# WELL_BORE_CODE                  0
# NPD_WELL_BORE_CODE              0
# NPD_WELL_BORE_NAME              0
# NPD_FIELD_CODE                  0
# NPD_FIELD_NAME                  0
# NPD_FACILITY_CODE               0
# NPD_FACILITY_NAME               0
# ON_STREAM_HRS                   0
# AVG_CHOKE_SIZE_P                0
# AVG_CHOKE_UOM                   0
# FLOW_KIND                       0
# WELL_TYPE                       0
# AVG_DOWNHOLE_PRESSURE_PSI       3
# AVG_DOWNHOLE_TEMPERATURE_F      3
# AVG_DP_TUBING_PSI               3
# AVG_ANNULUS_PRESS_PSI         729
# DP_CHOKE_SIZE_PSI               0
# AVG_WHP_P_PSI                   0
# BORE_WI_VOL_STB_D             746
# AVG_WHT_P                       0
# BORE_OIL_VOL_STB_D              0
# BORE_GAS_VOL_MSCF_D             0
# BORE_WAT_VOL_STB_D              0
# GOR_MSCF/STB                  316
# WCUT                          316
# dtype: int64
# Plot before cleaning
# Cleaning data
# ...

# %%
df_1.isna().sum()
# Out:
# WELL_BORE_CODE                            0
# NPD_WELL_BORE_CODE                        0
# NPD_WELL_BORE_NAME                        0
# NPD_FIELD_CODE                            0
# NPD_FIELD_NAME                            0
# NPD_FACILITY_CODE                         0
# NPD_FACILITY_NAME                         0
# ON_STREAM_HRS                             0
# AVG_CHOKE_SIZE_P                          0
# AVG_CHOKE_UOM                             0
# FLOW_KIND                                 0
# WELL_TYPE                                 0
# AVG_DOWNHOLE_PRESSURE_PSI                 0
# AVG_DOWNHOLE_TEMPERATURE_F                0
# AVG_DP_TUBING_PSI                         0
# DP_CHOKE_SIZE_PSI                         0
# AVG_WHP_P_PSI                             0
# AVG_WHT_P                                 0
# BORE_OIL_VOL_STB_D                        0
# BORE_GAS_VOL_MSCF_D                       0
# BORE_WAT_VOL_STB_D                        0
# ...

# %% [markdown]
# # DF2

# %%
plot_clean_plot(df_2)
# Out:
# how many nans before cleaning
# WELL_BORE_CODE                   0
# NPD_WELL_BORE_CODE               0
# NPD_WELL_BORE_NAME               0
# NPD_FIELD_CODE                   0
# NPD_FIELD_NAME                   0
# NPD_FACILITY_CODE                0
# NPD_FACILITY_NAME                0
# ON_STREAM_HRS                    0
# AVG_CHOKE_SIZE_P                 2
# AVG_CHOKE_UOM                    0
# FLOW_KIND                        0
# WELL_TYPE                        0
# AVG_DOWNHOLE_PRESSURE_PSI        6
# AVG_DOWNHOLE_TEMPERATURE_F       6
# AVG_DP_TUBING_PSI                6
# AVG_ANNULUS_PRESS_PSI            6
# DP_CHOKE_SIZE_PSI                6
# AVG_WHP_P_PSI                    6
# BORE_WI_VOL_STB_D             1165
# AVG_WHT_P                        6
# BORE_OIL_VOL_STB_D               0
# BORE_GAS_VOL_MSCF_D              0
# BORE_WAT_VOL_STB_D               0
# GOR_MSCF/STB                    42
# WCUT                            42
# dtype: int64
# Plot before cleaning
# ...

# %% [markdown]
# # DF3

# %%
plot_clean_plot(df_3)
# Out:
# how many nans before cleaning
# WELL_BORE_CODE                   0
# NPD_WELL_BORE_CODE               0
# NPD_WELL_BORE_NAME               0
# NPD_FIELD_CODE                   0
# NPD_FIELD_NAME                   0
# NPD_FACILITY_CODE                0
# NPD_FACILITY_NAME                0
# ON_STREAM_HRS                    0
# AVG_CHOKE_SIZE_P                44
# AVG_CHOKE_UOM                    0
# FLOW_KIND                        0
# WELL_TYPE                        0
# AVG_DOWNHOLE_PRESSURE_PSI        6
# AVG_DOWNHOLE_TEMPERATURE_F       6
# AVG_DP_TUBING_PSI                6
# AVG_ANNULUS_PRESS_PSI           13
# DP_CHOKE_SIZE_PSI                0
# AVG_WHP_P_PSI                    0
# BORE_WI_VOL_STB_D             3056
# AVG_WHT_P                        0
# BORE_OIL_VOL_STB_D               0
# BORE_GAS_VOL_MSCF_D              0
# BORE_WAT_VOL_STB_D               0
# GOR_MSCF/STB                   218
# WCUT                           219
# dtype: int64
# Plot before cleaning
# ...

# %%
df_3.isna().sum()
# Out:
# WELL_BORE_CODE                            0
# NPD_WELL_BORE_CODE                        0
# NPD_WELL_BORE_NAME                        0
# NPD_FIELD_CODE                            0
# NPD_FIELD_NAME                            0
# NPD_FACILITY_CODE                         0
# NPD_FACILITY_NAME                         0
# ON_STREAM_HRS                             0
# AVG_CHOKE_SIZE_P                          0
# AVG_CHOKE_UOM                             0
# FLOW_KIND                                 0
# WELL_TYPE                                 0
# AVG_DOWNHOLE_TEMPERATURE_F                0
# AVG_DP_TUBING_PSI                         0
# AVG_ANNULUS_PRESS_PSI                     0
# DP_CHOKE_SIZE_PSI                         0
# AVG_WHP_P_PSI                             0
# AVG_WHT_P                                 0
# BORE_OIL_VOL_STB_D                        0
# BORE_GAS_VOL_MSCF_D                       0
# BORE_WAT_VOL_STB_D                        0
# ...

# %% [markdown]
# # DF4

# %%
plot_clean_plot(df_4)
# Out:
# how many nans before cleaning
# WELL_BORE_CODE                   0
# NPD_WELL_BORE_CODE               0
# NPD_WELL_BORE_NAME               0
# NPD_FIELD_CODE                   0
# NPD_FIELD_NAME                   0
# NPD_FACILITY_CODE                0
# NPD_FACILITY_NAME                0
# ON_STREAM_HRS                    0
# AVG_CHOKE_SIZE_P               196
# AVG_CHOKE_UOM                    0
# FLOW_KIND                        0
# WELL_TYPE                        0
# AVG_DOWNHOLE_PRESSURE_PSI        6
# AVG_DOWNHOLE_TEMPERATURE_F       6
# AVG_DP_TUBING_PSI                6
# AVG_ANNULUS_PRESS_PSI          523
# DP_CHOKE_SIZE_PSI                0
# AVG_WHP_P_PSI                    0
# BORE_WI_VOL_STB_D             3056
# AVG_WHT_P                        0
# BORE_OIL_VOL_STB_D               0
# BORE_GAS_VOL_MSCF_D              0
# BORE_WAT_VOL_STB_D               0
# GOR_MSCF/STB                   332
# WCUT                           332
# dtype: int64
# Plot before cleaning
# ...

# %% [markdown]
# # DF5

# %%
plot_clean_plot(df_5)
# Out:
# how many nans before cleaning
# WELL_BORE_CODE                  0
# NPD_WELL_BORE_CODE              0
# NPD_WELL_BORE_NAME              0
# NPD_FIELD_CODE                  0
# NPD_FIELD_NAME                  0
# NPD_FACILITY_CODE               0
# NPD_FACILITY_NAME               0
# ON_STREAM_HRS                   0
# AVG_CHOKE_SIZE_P                0
# AVG_CHOKE_UOM                   0
# FLOW_KIND                       0
# WELL_TYPE                       0
# AVG_DOWNHOLE_PRESSURE_PSI       0
# AVG_DOWNHOLE_TEMPERATURE_F      0
# AVG_DP_TUBING_PSI               0
# AVG_ANNULUS_PRESS_PSI           0
# DP_CHOKE_SIZE_PSI               0
# AVG_WHP_P_PSI                   0
# BORE_WI_VOL_STB_D             978
# AVG_WHT_P                       0
# BORE_OIL_VOL_STB_D              0
# BORE_GAS_VOL_MSCF_D             0
# BORE_WAT_VOL_STB_D              0
# GOR_MSCF/STB                  211
# WCUT                          211
# dtype: int64
# Plot before cleaning
# Cleaning data
# ...

# %%
df_1.to_csv("processed_inputs/df1_cleaned.csv", index=True)
df_2.to_csv("processed_inputs/df2_cleaned.csv", index=True)
df_3.to_csv("processed_inputs/df3_cleaned.csv", index=True)
df_4.to_csv("processed_inputs/df4_cleaned.csv", index=True)
df_5.to_csv("processed_inputs/df5_cleaned.csv", index=True)
